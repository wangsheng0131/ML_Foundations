# %% [markdown]
# # 03 实现简单线性回归法

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([1., 2., 3., 4., 5.])
y=np.array([1., 3., 2., 3., 5.])

# %%
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)

# %%
x_mean=np.mean(x)
y_mean=np.mean(y)

# %%
num=0.
d=0.
for x_i,y_i in zip(x,y):
    num+=(x_i-x_mean)*(y_i-y_mean)
    d+=(x_i-x_mean)**2
a=num/d
b=y_mean-a*x_mean

# %%
y_hat=a*x+b

# %%
plt.scatter(x, y)
plt.plot(x, y_hat, color='r')
plt.axis([0, 6, 0, 6])
plt.show()

# %%
x_predict=6
y_predict=a*x_predict+b
y_predict
# Out:
# 5.2

# %% [markdown]
# ### 封装我们自己的SimpleLinearRegression

# %%
from playML.SimpleLinearRegression import SimpleLinearRegression1

# %%
reg1=SimpleLinearRegression1()
reg1.fit(x,y)
# Out:
# SimpleLinearRegression1()

# %%
reg1.predict(np.array([x_predict]))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-15-5f7c9cdf08a5> in <module>()
# ----> 1 reg1.predict(np.array([x_predict]))
#
# D:\study\coding\ML_Foundations\05-Linear-Regression\03-simple-Linear-Regression-Implementation\playML\SimpleLinearRegression.py in predict(self, x_predict)
#      34             "Simple Linear Regressor can only solve single feature training data."
#      35         assert self.a_ is not None and self.b_ is not None, \
# ---> 36             "must fit before predict!"
#      37
#      38         return np.array([self._predict(x) for x in x_predict])
#
# AssertionError: must fit before predict!
